# %%
import os
import ray
import json
import pickle
from dynaconf import Dynaconf
from tqdm.notebook import tqdm
from utils import check_path, convert_np_arrays, flatten_dict, env_creator
from ray.tune.logger import JsonLogger
from algorithms_with_statistics.ddqn_per import DDQNWithMPERAndLogging
from ray.tune.registry import register_env
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.9.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Init Ray
ray.init(
    num_cpus=5, num_gpus=1,
    include_dashboard=False,
    _system_config={"maximum_gcs_destroyed_actor_cached_count": 20},
)
# Out:
# 2024-04-20 13:59:53,677	INFO worker.py:1673 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.9.16', ray_version='2.8.0', ray_commit='105355bd253d6538ed34d331f6a4bdf0e38ace3a', protocol_version=None)
# (RolloutWorker pid=2728664) /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/gymnasium/envs/registration.py:531: UserWarning: WARN: Using the latest versioned environment `MiniGrid-LavaCrossingS9N1-v0` instead of the unversioned environment `MiniGrid-LavaCrossingS9N1`.
# (RolloutWorker pid=2728664)   logger.warn(

# %%
import mlflow
from mlflow.exceptions import MlflowException
from func_timeout import FunctionTimedOut
from botocore.exceptions import ConnectionClosedError

# %%
import datetime
# Config path
env_name = "MiniGrid-LavaCrossingS9N1"
run_name = int(datetime.datetime.now().timestamp())
log_path = "/home/seventheli/data/BER/experiments/logging/%s" % env_name
checkpoint_path = "/home/seventheli/data/BER/experiments/checkpoints/%s" % env_name
# Set mlflow
mlflow.set_tracking_uri("http://localhost:9999")
mlflow.set_experiment(experiment_name=env_name)
mlflow_client = mlflow.tracking.MlflowClient()
# Out:
# 2024/04/20 13:59:54 INFO mlflow.tracking.fluent: Experiment with name 'MiniGrid-LavaCrossingS9N1' does not exist. Creating a new experiment.

# %%
# Check path available
import shutil
check_path(log_path)
log_path = str(os.path.join(log_path, str(run_name)))
check_path(log_path)
if os.path.exists(log_path):
    shutil.rmtree(log_path)
check_path(log_path)
check_path(checkpoint_path)
checkpoint_path = os.path.join(checkpoint_path, str(run_name))
check_path(checkpoint_path)
if os.path.exists(checkpoint_path):
    shutil.rmtree(checkpoint_path)
check_path(checkpoint_path)

# %%
# Set hyper parameters
setting = "./settings/ddqn_minigrid.yml"
setting = Dynaconf(envvar_prefix="DYNACONF", settings_files=setting)

hyper_parameters = setting.hyper_parameters.to_dict()
hyper_parameters["logger_config"] = {"type": JsonLogger, "logdir": checkpoint_path}
hyper_parameters["env_config"] = {"id": env_name, "tile_size": 10, "img_size": 80, "max_steps": 100}

# %%
# Set model
import torch.nn as nn
from gymnasium.spaces.discrete import Discrete
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models import ModelCatalog


class CNN(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space: Discrete, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        self.conv_layers = nn.Sequential(
            nn.Conv2d(obs_space.shape[-1], 32, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.AdaptiveMaxPool2d((1, 1)),
            nn.Flatten(1)
        )

        self._features = None

    def import_from_h5(self, h5_file: str) -> None:
        pass

    def forward(self, input_dict, state, seq_lens):
        # logging.info(input_dict)
        # logging.info(input_dict["obs"].shape)
        self._features = input_dict["obs"].float()
        # permute b/c data comes in as [B, dim, dim, channels]:
        self._features = self._features.permute(0, 3, 1, 2)
        self._features = self.conv_layers(self._features)
        return self._features.flatten(1), state

    def value_function(self):
        pass

    

hyper_parameters["hiddens"] = [256, 128]
model_name = "CNN"
ModelCatalog.register_custom_model(model_name, CNN)
hyper_parameters["model"] = {
    "custom_model": model_name,
    "no_final_linear": True,
    "fcnet_hiddens": hyper_parameters["hiddens"] + [512],
    "custom_model_config": {
        "dueling_activation": "relu",
    }
}

# %%
# Set run object
run_name = "DDQN_%s" % env_name + "_PER_%s" % run_name
env_example = env_creator(hyper_parameters["env_config"])
obs, _ = env_example.reset()
step = env_example.step(1)
print(env_example.action_space, env_example.observation_space)
print(env_example)
print("log path: %s; check_path: %s" % (log_path, checkpoint_path))
register_env("MiniGrid", env_creator)
# Out:
# Discrete(7) Box(0, 255, (80, 80, 3), uint8)
# <TimeLimit<ResizeObservation<ImgObsWrapper<RGBImgObsWrapper<OrderEnforcing<PassiveEnvCheckerWGWGWGWGWGWGWGWGWG
# WGVVVR          WG
# WG              WG
# WG  VR          WG
# WG  VR          WG
# WG  VR          WG
# WG  VR          WG
# WG  VR        GGWG
# WGWGWGWGWGWGWGWGWG>>>>>>
# log path: /home/seventheli/data/BER/experiments/logging/MiniGrid-LavaCrossingS9N1/1713617994; check_path: /home/seventheli/data/BER/experiments/checkpoints/MiniGrid-LavaCrossingS9N1/1713617994
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/gymnasium/envs/registration.py:531: UserWarning: WARN: Using the latest versioned environment `MiniGrid-LavaCrossingS9N1-v0` instead of the unversioned environment `MiniGrid-LavaCrossingS9N1`.
#   logger.warn(

# %%
import matplotlib.pyplot as plt

plt.imshow(obs)
plt.axis('off')
plt.show()

# %%
# Set Trainer
trainer = DDQNWithMPERAndLogging(config=hyper_parameters, env="MiniGrid")
# Out:
# 2024-04-20 13:59:55,344	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# 2024-04-20 13:59:55,346	WARNING deprecation.py:50 -- DeprecationWarning: `algo = Algorithm(env='MiniGrid', ...)` has been deprecated. Use `algo = AlgorithmConfig().environment('MiniGrid').build()` instead. This will raise an error in the future!
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/utils/from_config.py:197: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   object_ = constructor(*ctor_args, **ctor_kwargs)

# %%
# Common setup
checkpoint_path = str(checkpoint_path)
# Save initial configuration
with open(os.path.join(checkpoint_path, "%s_config.pyl" % run_name), "wb") as f:
    _ = trainer.config.to_dict()
    pickle.dump(_, f)

# %%
mlflow_run = mlflow.start_run(run_name=run_name,
                              tags={"mlflow.user": "Local"})
# Log parameters
mlflow.log_params(hyper_parameters["replay_buffer_config"])
to_log = ['double_q', 'dueling', 'lr', 'n_step', 'num_steps_sampled_before_learning_starts',
          'rollout_fragment_length', 'target_network_update_freq', 'train_batch_size', 'min_sample_timesteps_per_iteration']
mlflow.log_params(
    {key: hyper_parameters[key] for key in to_log})

# %%
keys_to_extract_sam = {"episode_reward_max", "episode_reward_min", "episode_reward_mean"}
keys_to_extract_sta = {"num_agent_steps_sampled", "num_agent_steps_trained"}
keys_to_extract_buf = {"add_batch_time_ms", "replay_time_ms", "update_priorities_time_ms"}

# %%
mlflow.pytorch.log_model(trainer.get_policy().model, run_name)
model_uri = "runs:/%s/model_name" % mlflow_run.info.run_id
mlflow.register_model(model_uri, run_name, tags={"episode" : 0})
# Out:
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994'.
# 2024/04/20 14:00:09 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994, version 1
# Created version '1' of model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994'.
# <ModelVersion: aliases=[], creation_timestamp=1713618009889, current_stage='None', description='', last_updated_timestamp=1713618009889, name='DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994', run_id='5e7c842044434afc9cfb252697a7c905', run_link='', source='s3://jo-mlflow-ber/29/5e7c842044434afc9cfb252697a7c905/artifacts/model_name', status='READY', status_message='', tags={'episode': '0'}, user_id='', version='1'>

# %%
for i in tqdm(range(0, setting.log.max_run), ascii=True):
    result = trainer.train()
    time_used = result["time_total_s"]
    try:
        sampler = result.get("sampler_results", {}).copy()
        eva = result.get("evaluation", {}).copy()
        info = result.get("info", {}).copy()
        sam = {key: sampler[key] for key in keys_to_extract_sam if key in sampler}
        sta = {key: info[key] for key in keys_to_extract_sta if key in info}
        buf = flatten_dict(trainer.local_replay_buffer.stats())
        buf["est_size_gb"] = buf["est_size_bytes"] /1e9
        result['buffer'] = buf
        time_usage = info.get("learner", {}).get("time_usage", {})
        try:
            ex_info = {
                "reward_99" : calculate_adjusted_mean(result['hist_stats']['episode_reward']),
                "time_total_s": result['time_total_s']
            }
        except:
            ex_info = {}
        if eva:
            eva = {"eval_" + key: eva[key] for key in keys_to_extract_sam if key in eva}
        mlflow.log_metrics({**sam, **sta, **buf, **time_usage, **eva}, step=result["episodes_total"])
        if i % (setting.log.log * 50) == 0:
            trainer.save_checkpoint(checkpoint_path)
            mlflow.pytorch.log_model(trainer.get_policy().model, run_name)
            mlflow.register_model(model_uri, run_name, tags={
                "episode" : result["episodes_total"],
                "reward": sam["episode_reward_mean"],
            })
            mlflow.log_artifacts(log_path)
            mlflow.log_artifacts(checkpoint_path)
        if i % 10 == 0:
            tqdm.write("episode %d ; " % result["episodes_total"] +  " ".join(["%s : %f8" % (i, j)for i, j in sam.items()]))
    except FunctionTimedOut:
        tqdm.write("logging failed")
    except MlflowException:
        tqdm.write("logging failed")
    except ConnectionClosedError:
        tqdm.write("logging failed")
    with open(os.path.join(log_path, str(i) + ".json"), "w") as f:
        result["config"] = None
        json.dump(convert_np_arrays(result), f)
    if time_used >= setting.log.max_time:
        break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 2024-04-20 14:00:10,343	WARNING multi_agent_prioritized_replay_buffer.py:215 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# Registered model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994' already exists. Creating a new version of this model...
# 2024/04/20 14:00:43 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994, version 2
# Created version '2' of model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994'.
# episode 137 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# 2024-04-20 14:02:37,791	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# episode 1413 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 2492 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 3500 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 4507 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 5511 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 6519 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 7522 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 8527 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 9535 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 10539 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 11549 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 12561 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 13572 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 14579 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 15583 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 16595 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 17599 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 18606 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 19613 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 20620 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 21623 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 22628 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 23635 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 24641 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 25653 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 26660 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 27668 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 28671 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 29675 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 30683 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 31693 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 32702 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 33707 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 34716 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 35719 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 36727 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 37735 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 38739 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 39748 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 40753 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 41761 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 42765 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 43772 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 44782 ; episode_reward_mean : 0.0092688 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# episode 45787 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 46798 ; episode_reward_mean : 0.0163678 episode_reward_min : 0.0000008 episode_reward_max : 0.8916678
# episode 47818 ; episode_reward_mean : 0.0083888 episode_reward_min : 0.0000008 episode_reward_max : 0.8472228
# episode 48836 ; episode_reward_mean : 0.0277788 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# episode 49850 ; episode_reward_mean : 0.0352738 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# Registered model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994' already exists. Creating a new version of this model...
# 2024/04/20 22:07:33 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994, version 3
# Created version '3' of model 'DDQN_MiniGrid-LavaCrossingS9N1_PER_1713617994'.
# episode 50876 ; episode_reward_mean : 0.0351678 episode_reward_min : 0.0000008 episode_reward_max : 0.9611118
# episode 51906 ; episode_reward_mean : 0.0366678 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# episode 52923 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 53933 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 54959 ; episode_reward_mean : 0.0190878 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# episode 55986 ; episode_reward_mean : 0.0095438 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# episode 57016 ; episode_reward_mean : 0.0000008 episode_reward_min : 0.0000008 episode_reward_max : 0.0000008
# episode 58053 ; episode_reward_mean : 0.0360338 episode_reward_min : 0.0000008 episode_reward_max : 0.9638898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 for i in tqdm(range(0, setting.log.max_run), ascii=True):
# ----> 2     result = trainer.train()
#       3     time_used = result["time_total_s"]
#       4     try:
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/tune/trainable/trainable.py:339, in Trainable.train(self)
#     337 start = time.time()
#     338 try:
# --> 339     result = self.step()
#     340 except Exception as e:
#     341     skipped = skip_exceptions(e)
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:853, in Algorithm.step(self)
#     845     (
#     846         results,
#     847         train_iter_ctx,
#     848     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     849 # - No evaluation necessary, just run the next training iteration.
#     850 # - We have to evaluate in this training iteration, but no parallelism ->
#     851 #   evaluate after the training iteration is entirely done.
#     852 else:
# --> 853     results, train_iter_ctx = self._run_one_training_iteration()
#     855 # Sequential: Train (already done above), then evaluate.
#     856 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:2854, in Algorithm._run_one_training_iteration(self)
#    2852 with self._timers[TRAINING_ITERATION_TIMER]:
#    2853     if self.config._disable_execution_plan_api:
# -> 2854         results = self.training_step()
#    2855     else:
#    2856         results = next(self.train_exec_impl)
#
# File ~/research/Block_ExperienceReplay/algorithms_with_statistics/ddqn_per.py:54, in DDQNWithMPERAndLogging.training_step(self)
#      50 store_weight, sample_and_train_weight = calculate_rr_weights(self.config)
#      52 for _ in range(store_weight):
#      53     # Sample (MultiAgentBatch) from workers.
# ---> 54     new_sample_batch = synchronous_parallel_sample(
#      55         worker_set=self.workers, concat=True
#      56     )
#      58     # Update counters
#      59     self._counters[NUM_AGENT_STEPS_SAMPLED] += new_sample_batch.agent_steps()
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/execution/rollout_ops.py:85, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat)
#      82     sample_batches = [worker_set.local_worker().sample()]
#      83 # Loop over remote workers' `sample()` method in parallel.
#      84 else:
# ---> 85     sample_batches = worker_set.foreach_worker(
#      86         lambda w: w.sample(), local_worker=False, healthy_only=True
#      87     )
#      88     if worker_set.num_healthy_remote_workers() <= 0:
#      89         # There is no point staying in this loop, since we will not be able to
#      90         # get any new samples if we don't have any healthy remote workers left.
#      91         break
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/evaluation/worker_set.py:671, in WorkerSet.foreach_worker(self, func, local_worker, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     668 if local_worker and self.local_worker() is not None:
#     669     local_result = [func(self.local_worker())]
# --> 671 remote_results = self.__worker_manager.foreach_actor(
#     672     func,
#     673     healthy_only=healthy_only,
#     674     remote_actor_ids=remote_worker_ids,
#     675     timeout_seconds=timeout_seconds,
#     676     return_obj_refs=return_obj_refs,
#     677     mark_healthy=mark_healthy,
#     678 )
#     680 handle_remote_call_result_errors(remote_results, self._ignore_worker_failures)
#     682 # With application errors handled, return good results.
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/utils/actor_manager.py:592, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     583     func, remote_actor_ids = self._filter_func_and_remote_actor_id_by_state(
#     584         func, remote_actor_ids
#     585     )
#     587 remote_calls = self.__call_actors(
#     588     func=func,
#     589     remote_actor_ids=remote_actor_ids,
#     590 )
# --> 592 _, remote_results = self.__fetch_result(
#     593     remote_actor_ids=remote_actor_ids,
#     594     remote_calls=remote_calls,
#     595     tags=[None] * len(remote_calls),
#     596     timeout_seconds=timeout_seconds,
#     597     return_obj_refs=return_obj_refs,
#     598     mark_healthy=mark_healthy,
#     599 )
#     601 return remote_results
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/utils/actor_manager.py:460, in FaultTolerantActorManager.__fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     457 if not remote_calls:
#     458     return [], RemoteCallResults()
# --> 460 ready, _ = ray.wait(
#     461     remote_calls,
#     462     num_returns=len(remote_calls),
#     463     timeout=timeout,
#     464     # Make sure remote results are fetched locally in parallel.
#     465     fetch_local=not return_obj_refs,
#     466 )
#     468 # Remote data should already be fetched to local object store at this point.
#     469 remote_results = RemoteCallResults()
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/_private/worker.py:2771, in wait(object_refs, num_returns, timeout, fetch_local)
#    2769 timeout = timeout if timeout is not None else 10**6
#    2770 timeout_milliseconds = int(timeout * 1000)
# -> 2771 ready_ids, remaining_ids = worker.core_worker.wait(
#    2772     object_refs,
#    2773     num_returns,
#    2774     timeout_milliseconds,
#    2775     worker.current_task_id,
#    2776     fetch_local,
#    2777 )
#    2778 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3434, in ray._raylet.CoreWorker.wait()
#
# File python/ray/_raylet.pyx:449, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
trainer.save_checkpoint(checkpoint_path)
mlflow.log_artifacts(log_path)
mlflow.log_artifacts(checkpoint_path)

# %%
mlflow.end_run()
