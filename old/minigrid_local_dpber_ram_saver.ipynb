# %%
import os
import ray
import json
import pickle
from dynaconf import Dynaconf
from tqdm.notebook import tqdm
from utils import check_path, convert_np_arrays, flatten_dict, env_creator
from ray.tune.logger import JsonLogger
from algorithms.apex_ddqn import ApexDDQNWithDPBER
from replay_buffer.mpber_ram_saver import MultiAgentPrioritizedBlockReplayBuffer
from ray.tune.registry import register_env
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.9.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2024-04-20 23:28:22,114	WARNING __init__.py:10 -- ApexDQN has/have been moved to `rllib_contrib` and will no longer be maintained by the RLlib team. You can still use it/them normally inside RLlib util Ray 2.8, but from Ray 2.9 on, all `rllib_contrib` algorithms will no longer be part of the core repo, and will therefore have to be installed separately with pinned dependencies for e.g. ray[rllib] and other packages! See https://github.com/ray-project/ray/tree/master/rllib_contrib#rllib-contrib for more information on the RLlib contrib effort.

# %%
# Init Ray
ray.init(
    num_cpus=20, num_gpus=1,
    include_dashboard=False,
    _system_config={"maximum_gcs_destroyed_actor_cached_count": 200},
)
# Out:
# 2024-04-20 23:28:24,097	INFO worker.py:1673 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.9.16', ray_version='2.8.0', ray_commit='105355bd253d6538ed34d331f6a4bdf0e38ace3a', protocol_version=None)
# (RolloutWorker pid=3682076) 2024-04-20 23:28:27,683	WARNING __init__.py:10 -- ApexDQN has/have been moved to `rllib_contrib` and will no longer be maintained by the RLlib team. You can still use it/them normally inside RLlib util Ray 2.8, but from Ray 2.9 on, all `rllib_contrib` algorithms will no longer be part of the core repo, and will therefore have to be installed separately with pinned dependencies for e.g. ray[rllib] and other packages! See https://github.com/ray-project/ray/tree/master/rllib_contrib#rllib-contrib for more information on the RLlib contrib effort.
# (RolloutWorker pid=3682076) /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/gymnasium/envs/registration.py:531: UserWarning: WARN: Using the latest versioned environment `MiniGrid-LavaCrossingS9N1-v0` instead of the unversioned environment `MiniGrid-LavaCrossingS9N1`.
# (RolloutWorker pid=3682076)   logger.warn(
# (MultiAgentPrioritizedBlockReplayBuffer pid=3682422) 2024-04-20 23:28:40,545	WARNING multi_agent_prioritized_replay_buffer.py:215 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.

# %%
import mlflow
from mlflow.exceptions import MlflowException
from func_timeout import FunctionTimedOut
from botocore.exceptions import ConnectionClosedError

# %%
import datetime
# Config path
env_name = "MiniGrid-LavaCrossingS9N1"
run_name = int(datetime.datetime.now().timestamp())
log_path = "/home/seventheli/data/BER/experiments/logging/%s" % env_name
checkpoint_path = "/home/seventheli/data/BER/experiments/checkpoints/%s" % env_name
# Set mlflow
mlflow.set_tracking_uri("http://localhost:9999")
mlflow.set_experiment(experiment_name=env_name)
mlflow_client = mlflow.tracking.MlflowClient()

# %%
import scipy.stats as stats
import numpy as np

def calculate_adjusted_mean(rewards):
    """
    Calculate the mean of rewards after excluding the top and bottom 5% of the data.

    Args:
    rewards (list): A list of reward values.

    Returns:
    float: Mean of the middle 99% of the rewards.
    """
    # Calculate percentiles to exclude the top and bottom 1%
    low, high = np.percentile(rewards, [0.5, 99.5])

    # Filter the rewards to include only the middle 99%
    filtered_rewards = [reward for reward in rewards if low <= reward <= high]

    # Compute the mean of the filtered rewards
    adjusted_mean = np.mean(filtered_rewards)

    return adjusted_mean

# %%
# Check path available
import shutil
check_path(log_path)
log_path = str(os.path.join(log_path, str(run_name)))
check_path(log_path)
if os.path.exists(log_path):
    shutil.rmtree(log_path)
check_path(log_path)
check_path(checkpoint_path)
checkpoint_path = os.path.join(checkpoint_path, str(run_name))
check_path(checkpoint_path)
if os.path.exists(checkpoint_path):
    shutil.rmtree(checkpoint_path)
check_path(checkpoint_path)

# %%
# Set hyper parameters
setting = "./settings/apex_minigrid.yml"
setting = Dynaconf(envvar_prefix="DYNACONF", settings_files=setting)

hyper_parameters = setting.hyper_parameters.to_dict()
hyper_parameters["logger_config"] = {"type": JsonLogger, "logdir": checkpoint_path}
hyper_parameters["env_config"] = {"id": env_name, "tile_size": 10, "img_size": 80, "max_steps": 100}

# %%
# Set model
import torch.nn as nn
from gymnasium.spaces.discrete import Discrete
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models import ModelCatalog


class CNN(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space: Discrete, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        self.conv_layers = nn.Sequential(
            nn.Conv2d(obs_space.shape[-1], 32, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.AdaptiveMaxPool2d((1, 1)),
            nn.Flatten(1)
        )

        self._features = None

    def import_from_h5(self, h5_file: str) -> None:
        pass

    def forward(self, input_dict, state, seq_lens):
        # logging.info(input_dict)
        # logging.info(input_dict["obs"].shape)
        self._features = input_dict["obs"].float()
        # permute b/c data comes in as [B, dim, dim, channels]:
        self._features = self._features.permute(0, 3, 1, 2)
        self._features = self.conv_layers(self._features)
        return self._features.flatten(1), state

    def value_function(self):
        pass

    

hyper_parameters["hiddens"] = [256, 128]
model_name = "CNN"
ModelCatalog.register_custom_model(model_name, CNN)
hyper_parameters["model"] = {
    "custom_model": model_name,
    "no_final_linear": True,
    "fcnet_hiddens": hyper_parameters["hiddens"] + [512],
    "custom_model_config": {
        "dueling_activation": "relu",
    }
}

# %%
# Set run object
run_name = "APEX_%s" % env_name + "_DPBER_RamSaver_%s" % run_name
env_example = env_creator(hyper_parameters["env_config"])
obs, _ = env_example.reset()
step = env_example.step(1)
print(env_example.action_space, env_example.observation_space)
print(env_example)
print("log path: %s; check_path: %s" % (log_path, checkpoint_path))
register_env("MiniGrid", env_creator)
# Out:
# Discrete(7) Box(0, 255, (80, 80, 3), uint8)
# <TimeLimit<ResizeObservation<ImgObsWrapper<RGBImgObsWrapper<OrderEnforcing<PassiveEnvCheckerWGWGWGWGWGWGWGWGWG
# WGVVVR          WG
# WG  VR          WG
# WG  VR          WG
# WG  VR          WG
# WG  VR          WG
# WG  VR          WG
# WG            GGWG
# WGWGWGWGWGWGWGWGWG>>>>>>
# log path: /home/seventheli/data/BER/experiments/logging/MiniGrid-LavaCrossingS9N1/1713652105; check_path: /home/seventheli/data/BER/experiments/checkpoints/MiniGrid-LavaCrossingS9N1/1713652105
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/gymnasium/envs/registration.py:531: UserWarning: WARN: Using the latest versioned environment `MiniGrid-LavaCrossingS9N1-v0` instead of the unversioned environment `MiniGrid-LavaCrossingS9N1`.
#   logger.warn(

# %%
import matplotlib.pyplot as plt

# Plotting the image without the 4th dimension (assuming it's an alpha channel or similar)
plt.imshow(obs)
plt.axis('off')
plt.show()

# %%
# Set Replay Buffer
sub_buffer_size = 32
replay_buffer_config = {
    **hyper_parameters["replay_buffer_config"],
    "type": MultiAgentPrioritizedBlockReplayBuffer,
    "obs_space": env_example.observation_space,
    "action_space": env_example.action_space,
    "sub_buffer_size": sub_buffer_size,
    "worker_side_prioritization": False,
    "replay_buffer_shards_colocated_with_driver": True,
    "rollout_fragment_length": hyper_parameters["rollout_fragment_length"],
    "num_save": 200,
    "split_mini_batch": 10,
    "store": 2000
}
hyper_parameters["replay_buffer_config"] = replay_buffer_config
hyper_parameters["train_batch_size"] = int(hyper_parameters["train_batch_size"] / sub_buffer_size)
hyper_parameters["optimizer"] = {"num_replay_buffer_shards": 10}

# %%
# Set Trainer
trainer = ApexDDQNWithDPBER(config=hyper_parameters, env="MiniGrid")
# Out:
# 2024-04-20 23:28:25,822	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/apex_dqn/` has been deprecated. Use `rllib_contrib/apex_dqn/` instead. This will raise an error in the future!
# 2024-04-20 23:28:25,822	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# 2024-04-20 23:28:25,824	WARNING deprecation.py:50 -- DeprecationWarning: `algo = Algorithm(env='MiniGrid', ...)` has been deprecated. Use `algo = AlgorithmConfig().environment('MiniGrid').build()` instead. This will raise an error in the future!
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/utils/from_config.py:197: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   object_ = constructor(*ctor_args, **ctor_kwargs)

# %%
trainer.learner_thread.local_worker.get_policy().model
# Out:
# CNN_as_DQNTorchModel(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): AdaptiveMaxPool2d(output_size=(1, 1))
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (advantage_module): Sequential(
#     (dueling_A_0): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): ReLU()
#       )
#     )
#     (dueling_A_1): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): ReLU()
#       )
#     )
#     (A): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=128, out_features=7, bias=True)
#       )
#     )
#   )
#   (value_module): Sequential(
#     (dueling_V_0): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): ReLU()
#       )
#     )
#     (dueling_V_1): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): ReLU()
#       )
#     )
#     (V): SlimFC(
#       (_model): Sequential(
#         (0): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
# Common setup
checkpoint_path = str(checkpoint_path)
# Save initial configuration
with open(os.path.join(checkpoint_path, "%s_config.pyl" % run_name), "wb") as f:
    _ = trainer.config.to_dict()
    pickle.dump(_, f)

# %%
mlflow_run = mlflow.start_run(run_name=run_name,
                              tags={"mlflow.user": "Local"})
# Log parameters
mlflow.log_params(hyper_parameters["replay_buffer_config"])
to_log = ['num_workers', 'double_q', 'dueling', 'lr', 'n_step', 'num_steps_sampled_before_learning_starts',
          'rollout_fragment_length', 'target_network_update_freq', 'train_batch_size', 'min_sample_timesteps_per_iteration']
mlflow.log_params(
    {key: hyper_parameters[key] for key in to_log})

# %%
keys_to_extract_sam = {"episode_reward_max", "episode_reward_min", "episode_reward_mean"}
keys_to_extract_sta = {"num_agent_steps_sampled", "num_agent_steps_trained"}
keys_to_extract_buf = {"add_batch_time_ms", "replay_time_ms", "update_priorities_time_ms"}

# %%
mlflow.pytorch.log_model(trainer.get_policy().model, run_name)
model_uri = "runs:/%s/model_name" % mlflow_run.info.run_id
mlflow.register_model(model_uri, run_name, tags={"episode" : 0})
# Out:
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# Successfully registered model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105'.
# 2024/04/20 23:28:40 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105, version 1
# Created version '1' of model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105'.
# <ModelVersion: aliases=[], creation_timestamp=1713652120143, current_stage='None', description='', last_updated_timestamp=1713652120143, name='APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105', run_id='2166b97b6abc4ebe8486df4a526d054c', run_link='', source='s3://jo-mlflow-ber/29/2166b97b6abc4ebe8486df4a526d054c/artifacts/model_name', status='READY', status_message='', tags={'episode': '0'}, user_id='', version='1'>

# %%
setting.log.max_run
# Out:
# 10000

# %%
for i in tqdm(range(0, setting.log.max_run)):
    result = trainer.train()
    time_used = result["time_total_s"]
    try:
        sampler = result.get("sampler_results", {}).copy()
        eva = result.get("evaluation", {}).copy()
        info = result.get("info", {}).copy()
        sam = {key: sampler[key] for key in keys_to_extract_sam if key in sampler}
        sta = {key: info[key] for key in keys_to_extract_sta if key in info}
        buf = flatten_dict(info.get("replay_shard_0", {}))
        buf["est_size_bytes"] = buf["est_size_bytes"] * hyper_parameters["optimizer"]["num_replay_buffer_shards"]
        buf["est_size_gb"] = buf["est_size_bytes"] /1e9
        result['buffer'] = buf
        time_usage = info.get("learner", {}).get("time_usage", {})
        try:
            ex_info = {
                "reward_99" : calculate_adjusted_mean(result['hist_stats']['episode_reward']),
                "time_total_s": result['time_total_s']
            }
        except:
            ex_info = {}
        if eva:
            eva = {"eval_" + key: eva[key] for key in keys_to_extract_sam if key in eva}
        mlflow.log_metrics({**sam, **sta, **buf, **time_usage, **eva}, step=result["episodes_total"])
        if i % (setting.log.log * 50) == 0:
            trainer.save_checkpoint(checkpoint_path)
            mlflow.pytorch.log_model(trainer.get_policy().model, run_name)
            mlflow.register_model(model_uri, run_name, tags={
                "episode" : result["episodes_total"],
                "reward": sam["episode_reward_mean"],
            })
            mlflow.log_artifacts(log_path)
            mlflow.log_artifacts(checkpoint_path)
        if i % 10 == 0:
            tqdm.write("episode %d ; " % result["episodes_total"] +  " ".join(["%s : %f8" % (i, j)for i, j in sam.items()]))
    except FunctionTimedOut:
        tqdm.write("logging failed")
    except MlflowException:
        tqdm.write("logging failed")
    except ConnectionClosedError:
        tqdm.write("logging failed")
    with open(os.path.join(log_path, str(i) + ".json"), "w") as f:
        result["config"] = None
        json.dump(convert_np_arrays(result), f)
    if time_used >= setting.log.max_time:
        break
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/ray/rllib/utils/metrics/window_stat.py:50: RuntimeWarning: Mean of empty slice
#   return float(np.nanmean(self.items[: self.count]))
# /home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# Registered model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105' already exists. Creating a new version of this model...
# 2024/04/20 23:29:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105, version 2
# Created version '2' of model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105'.
# episode 160 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 878 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 1505 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 2134 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 2761 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 3390 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 4018 ; episode_reward_mean : 0.0000008 episode_reward_max : 0.0000008 episode_reward_min : 0.0000008
# episode 4661 ; episode_reward_mean : 0.0384448 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 5343 ; episode_reward_mean : 0.0838618 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 6044 ; episode_reward_mean : 0.1134178 episode_reward_max : 0.9583338 episode_reward_min : 0.0000008
# episode 6774 ; episode_reward_mean : 0.2068898 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 7520 ; episode_reward_mean : 0.1630568 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 8307 ; episode_reward_mean : 0.2624178 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 9089 ; episode_reward_mean : 0.2312508 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 9929 ; episode_reward_mean : 0.2904178 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 10734 ; episode_reward_mean : 0.3025288 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 11641 ; episode_reward_mean : 0.3036398 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 12500 ; episode_reward_mean : 0.4338318 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 13414 ; episode_reward_mean : 0.3918898 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 14349 ; episode_reward_mean : 0.3404448 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 15305 ; episode_reward_mean : 0.4462228 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 16296 ; episode_reward_mean : 0.4181118 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 17285 ; episode_reward_mean : 0.4614448 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 18313 ; episode_reward_mean : 0.5273238 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 19385 ; episode_reward_mean : 0.4709828 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 20433 ; episode_reward_mean : 0.4590418 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 21546 ; episode_reward_mean : 0.5556988 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 22698 ; episode_reward_mean : 0.5141598 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 23814 ; episode_reward_mean : 0.5572368 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 25071 ; episode_reward_mean : 0.5848648 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 26374 ; episode_reward_mean : 0.7169838 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 27683 ; episode_reward_mean : 0.5857618 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 29066 ; episode_reward_mean : 0.5974558 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 30544 ; episode_reward_mean : 0.6774968 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 31974 ; episode_reward_mean : 0.6220078 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 33646 ; episode_reward_mean : 0.7300268 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 35408 ; episode_reward_mean : 0.7392588 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 37231 ; episode_reward_mean : 0.7312388 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 39143 ; episode_reward_mean : 0.7811508 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 41126 ; episode_reward_mean : 0.7894068 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 43188 ; episode_reward_mean : 0.8034828 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 45355 ; episode_reward_mean : 0.7934908 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 47639 ; episode_reward_mean : 0.8053488 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 50322 ; episode_reward_mean : 0.8847278 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 53158 ; episode_reward_mean : 0.9031718 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 56309 ; episode_reward_mean : 0.9228268 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 59290 ; episode_reward_mean : 0.8985608 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 62319 ; episode_reward_mean : 0.8831248 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 65438 ; episode_reward_mean : 0.8811058 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 68811 ; episode_reward_mean : 0.9417578 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# Registered model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105' already exists. Creating a new version of this model...
# 2024/04/21 07:33:48 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105, version 3
# Created version '3' of model 'APEX_MiniGrid-LavaCrossingS9N1_DPBER_RamSaver_1713652105'.
# episode 72411 ; episode_reward_mean : 0.9411878 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 76105 ; episode_reward_mean : 0.9427738 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 79594 ; episode_reward_mean : 0.9296488 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 83132 ; episode_reward_mean : 0.9382208 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 86548 ; episode_reward_mean : 0.8954928 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 90497 ; episode_reward_mean : 0.9570548 episode_reward_max : 0.9638898 episode_reward_min : 0.7916678
# episode 94531 ; episode_reward_mean : 0.9576818 episode_reward_max : 0.9638898 episode_reward_min : 0.8333338
# episode 98520 ; episode_reward_mean : 0.9553988 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 102663 ; episode_reward_mean : 0.9566618 episode_reward_max : 0.9638898 episode_reward_min : 0.8027788
# episode 106661 ; episode_reward_mean : 0.9560488 episode_reward_max : 0.9638898 episode_reward_min : 0.7861118
# episode 110759 ; episode_reward_mean : 0.9597138 episode_reward_max : 0.9638898 episode_reward_min : 0.9555568
# episode 114886 ; episode_reward_mean : 0.9590598 episode_reward_max : 0.9638898 episode_reward_min : 0.7694448
# episode 119032 ; episode_reward_mean : 0.9520118 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 123216 ; episode_reward_mean : 0.9590448 episode_reward_max : 0.9638898 episode_reward_min : 0.8500008
# episode 127421 ; episode_reward_mean : 0.9594938 episode_reward_max : 0.9638898 episode_reward_min : 0.9138898
# episode 131636 ; episode_reward_mean : 0.9599368 episode_reward_max : 0.9638898 episode_reward_min : 0.9416678
# episode 135859 ; episode_reward_mean : 0.9592338 episode_reward_max : 0.9638898 episode_reward_min : 0.8666678
# episode 140064 ; episode_reward_mean : 0.9593728 episode_reward_max : 0.9638898 episode_reward_min : 0.8416678
# episode 144292 ; episode_reward_mean : 0.9585328 episode_reward_max : 0.9638898 episode_reward_min : 0.8444448
# episode 148486 ; episode_reward_mean : 0.9583278 episode_reward_max : 0.9638898 episode_reward_min : 0.8416678
# episode 152769 ; episode_reward_mean : 0.9588448 episode_reward_max : 0.9638898 episode_reward_min : 0.8555568
# episode 157003 ; episode_reward_mean : 0.9586828 episode_reward_max : 0.9638898 episode_reward_min : 0.8388898
# episode 161238 ; episode_reward_mean : 0.9593888 episode_reward_max : 0.9638898 episode_reward_min : 0.7777788
# episode 165501 ; episode_reward_mean : 0.9592058 episode_reward_max : 0.9638898 episode_reward_min : 0.8111118
# episode 169765 ; episode_reward_mean : 0.9594668 episode_reward_max : 0.9638898 episode_reward_min : 0.8444448
# episode 174019 ; episode_reward_mean : 0.9556578 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 178264 ; episode_reward_mean : 0.9581118 episode_reward_max : 0.9638898 episode_reward_min : 0.7583338
# episode 182515 ; episode_reward_mean : 0.9565388 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 186749 ; episode_reward_mean : 0.9578478 episode_reward_max : 0.9638898 episode_reward_min : 0.7916678
# episode 191030 ; episode_reward_mean : 0.9596778 episode_reward_max : 0.9638898 episode_reward_min : 0.8611118
# episode 195264 ; episode_reward_mean : 0.9598348 episode_reward_max : 0.9638898 episode_reward_min : 0.9444448
# episode 199571 ; episode_reward_mean : 0.9599308 episode_reward_max : 0.9638898 episode_reward_min : 0.9500008
# episode 203861 ; episode_reward_mean : 0.9597618 episode_reward_max : 0.9638898 episode_reward_min : 0.9166678
# episode 208140 ; episode_reward_mean : 0.9596938 episode_reward_max : 0.9638898 episode_reward_min : 0.9055568
# episode 212432 ; episode_reward_mean : 0.9589238 episode_reward_max : 0.9638898 episode_reward_min : 0.7833338
# episode 216652 ; episode_reward_mean : 0.9601198 episode_reward_max : 0.9638898 episode_reward_min : 0.9472228
# episode 220933 ; episode_reward_mean : 0.9547708 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 225171 ; episode_reward_mean : 0.9597068 episode_reward_max : 0.9638898 episode_reward_min : 0.8250008
# episode 229409 ; episode_reward_mean : 0.9576198 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 233638 ; episode_reward_mean : 0.9596138 episode_reward_max : 0.9638898 episode_reward_min : 0.8638898
# episode 237930 ; episode_reward_mean : 0.9589798 episode_reward_max : 0.9638898 episode_reward_min : 0.8250008
# episode 242218 ; episode_reward_mean : 0.9593358 episode_reward_max : 0.9638898 episode_reward_min : 0.8361118
# episode 246503 ; episode_reward_mean : 0.9584808 episode_reward_max : 0.9638898 episode_reward_min : 0.8250008
# episode 250803 ; episode_reward_mean : 0.9596048 episode_reward_max : 0.9638898 episode_reward_min : 0.9000008
# episode 255106 ; episode_reward_mean : 0.9571158 episode_reward_max : 0.9638898 episode_reward_min : 0.0000008
# episode 259383 ; episode_reward_mean : 0.9592618 episode_reward_max : 0.9638898 episode_reward_min : 0.8527788
# episode 263695 ; episode_reward_mean : 0.9596558 episode_reward_max : 0.9638898 episode_reward_min : 0.8722228
# episode 267963 ; episode_reward_mean : 0.9598288 episode_reward_max : 0.9638898 episode_reward_min : 0.8361118
# episode 272268 ; episode_reward_mean : 0.9599278 episode_reward_max : 0.9638898 episode_reward_min : 0.9305568
# episode 276571 ; episode_reward_mean : 0.9593828 episode_reward_max : 0.9638898 episode_reward_min : 0.8611118
# Exception ignored in: <function tqdm.__del__ at 0x7fddc0699670>
# Traceback (most recent call last):
#   File "/home/seventheli/anaconda3/envs/ber_gym_28/lib/python3.9/site-packages/tqdm/std.py", line 1147, in __del__
#     def __del__(self):
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
mlflow.log_artifacts(log_path)
mlflow.log_artifacts(checkpoint_path)

# %%
mlflow.end_run()
